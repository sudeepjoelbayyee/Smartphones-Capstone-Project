# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("..\Data Cleaning\smartphones_cleaned_v4.csv")

# %%
df
# Out:
#       brand_name                                              model   price  \
# 0        oneplus                                     OnePlus V Flip   79990
# 1          tecno                              Tecno Camon 20 Pro 4G   16990
# 2         xiaomi         Xiaomi Redmi Note 12 Pro (8GB RAM + 256GB)   23799
# 3         realme                                        Realme 8 5G   16999
# 4         xiaomi                         Xiaomi Redmi Note 10 JE 5G   10490
# 5         lenovo                                Lenovo Legion Pro 2   59999
# 6        samsung            Samsung Galaxy M52 5G (8GB RAM + 128GB)   23990
# 7       micromax                                     Micromax IN 2C    5790
# 8           sony                                   Sony Xperia 10 V   39999
# 9         xiaomi            Xiaomi Redmi 10 Prime (6GB RAM + 128GB)   13458
# 10          poco                                         POCO X5 5G   18999
# ...

# %%
df.isnull().sum()
# Out:
# brand_name                     0
# model                          0
# price                          0
# rating                       265
# has_5g                         0
# has_nfc                        0
# has_ir_blaster                 0
# processor_brand               83
# num_cores                      9
# processor_speed              151
# ram_capacity                   0
# internal_memory                0
# battery_capacity              12
# fast_charging_available        0
# fast_charging                504
# num_rear_cameras               0
# num_front_cameras              0
# screen_size                    0
# resolution                     0
# refresh_rate                   0
# os                             0
# extended_memory_available      0
# extended_upto                  0
# primary_camera_rear            0
# primary_camera_front           6
# dtype: int64

# %% [markdown]
# ### Rating

# %%
df[~(df['rating'].isnull()) & (df['brand_name'] == 'meizu')]['rating'].median()
# Out:
# 87.5

# %%
temp = df[(df['rating'].isnull()) & (df['brand_name'] == 'meizu')]

# %%
df.loc[temp.index,'rating'] = 87.5

# %%
df.isnull().sum()
# Out:
# brand_name                     0
# model                          0
# price                          0
# rating                         0
# has_5g                         0
# has_nfc                        0
# has_ir_blaster                 0
# processor_brand               83
# num_cores                      9
# processor_speed              151
# ram_capacity                   0
# internal_memory                0
# battery_capacity              12
# fast_charging_available        0
# fast_charging                504
# num_rear_cameras               0
# num_front_cameras              0
# screen_size                    0
# resolution                     0
# refresh_rate                   0
# os                             0
# extended_memory_available      0
# extended_upto                  0
# primary_camera_rear            0
# primary_camera_front           6
# dtype: int64

# %%
df[(df['rating'].isnull())]['brand_name'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# ### Processor Brand

# %%
df.isnull().sum()
# Out:
# brand_name                     0
# model                          0
# price                          0
# rating                         0
# has_5g                         0
# has_nfc                        0
# has_ir_blaster                 0
# processor_brand               83
# num_cores                      9
# processor_speed              151
# ram_capacity                   0
# internal_memory                0
# battery_capacity              12
# fast_charging_available        0
# fast_charging                504
# num_rear_cameras               0
# num_front_cameras              0
# screen_size                    0
# resolution                     0
# refresh_rate                   0
# os                             0
# extended_memory_available      0
# extended_upto                  0
# primary_camera_rear            0
# primary_camera_front           6
# dtype: int64

# %%
df[df['processor_brand'].isnull()]['brand_name'].value_counts()
# Out:
# brand_name
# ikall       22
# samsung     16
# itel         7
# realme       6
# huawei       6
# tecno        4
# nokia        3
# nothing      2
# nubia        2
# oppo         2
# lenovo       2
# infinix      2
# xiaomi       2
# vivo         1
# lg           1
# motorola     1
# tesla        1
# jio          1
# poco         1
# lava         1
# Name: count, dtype: int64

# %%
df[df['brand_name'] == 'ikall']
# Out:
#      brand_name                       model  price  rating  has_5g  has_nfc  \
# 147       ikall                iKall Z6 New   6499    64.0   False    False
# 185       ikall                   iKall Z12   6798    64.0   False    False
# 237       ikall        iKall Z19 Ultra Plus   8059    64.0   False    False
# 258       ikall               iKall Z17 New   7219    60.0   False    False
# 338       ikall               iKall Z17 Pro   7284    60.0   False    False
# 407       ikall  iKall Z1 (3GB RAM + 32 GB)   4799    64.0   False    False
# 605       ikall               iKall S1 Plus   9999    66.0   False    False
# 685       ikall                    iKall Z5   4499    64.0   False    False
# 692       ikall               iKall Z18 New   7989    64.0   False    False
# 738       ikall               iKall Z19 Pro   7229    60.0   False    False
# 1145      ikall                   iKall Z13   6299    61.0   False    False
# ...

# %%
df.loc[df[df['brand_name'] == 'ikall'].index,'processor_brand'] = 'mediatek'

# %%
df[df['brand_name'] == 'ikall']
# Out:
#      brand_name                       model  price  rating  has_5g  has_nfc  \
# 147       ikall                iKall Z6 New   6499    64.0   False    False
# 185       ikall                   iKall Z12   6798    64.0   False    False
# 237       ikall        iKall Z19 Ultra Plus   8059    64.0   False    False
# 258       ikall               iKall Z17 New   7219    60.0   False    False
# 338       ikall               iKall Z17 Pro   7284    60.0   False    False
# 407       ikall  iKall Z1 (3GB RAM + 32 GB)   4799    64.0   False    False
# 605       ikall               iKall S1 Plus   9999    66.0   False    False
# 685       ikall                    iKall Z5   4499    64.0   False    False
# 692       ikall               iKall Z18 New   7989    64.0   False    False
# 738       ikall               iKall Z19 Pro   7229    60.0   False    False
# 1145      ikall                   iKall Z13   6299    61.0   False    False
# ...

# %%
df[df['processor_brand'].isnull()]['brand_name'].value_counts()
# Out:
# brand_name
# samsung     16
# itel         7
# realme       6
# huawei       6
# tecno        4
# nokia        3
# nothing      2
# nubia        2
# oppo         2
# lenovo       2
# infinix      2
# xiaomi       2
# vivo         1
# lg           1
# motorola     1
# tesla        1
# jio          1
# poco         1
# lava         1
# Name: count, dtype: int64

# %%
df[(df['processor_brand'].isnull()) & (df['brand_name'] == 'samsung')]

# %%
df[~(df['processor_brand'].isnull()) & (df['brand_name'] == 'samsung')]['processor_brand'].value_counts()
# Out:
# processor_brand
# exynos        96
# snapdragon    87
# helio         29
# dimensity     22
# unisoc         3
# Name: count, dtype: int64

# %%
temp = df[(df['processor_brand'].isnull()) & (df['brand_name'] == 'samsung')].head(8)

# %%
df.loc[temp.index,'processor_brand'] = 'exynos'

# %%
df.loc[df[(df['processor_brand'].isnull()) & (df['brand_name'] == 'samsung')].index,'processor_brand'] = 'snapdragon'

# %%
df[(df['processor_brand'].isnull()) & (df['brand_name'] == 'samsung')]
# Out:
# Empty DataFrame
# Columns: [brand_name, model, price, rating, has_5g, has_nfc, has_ir_blaster, processor_brand, num_cores, processor_speed, ram_capacity, internal_memory, battery_capacity, fast_charging_available, fast_charging, num_rear_cameras, num_front_cameras, screen_size, resolution, refresh_rate, os, extended_memory_available, extended_upto, primary_camera_rear, primary_camera_front]
# Index: []

# %%
df[(df['processor_brand'].isnull())]['brand_name'].value_counts()
# Out:
# brand_name
# itel        7
# huawei      6
# realme      6
# tecno       4
# nokia       3
# infinix     2
# xiaomi      2
# lenovo      2
# oppo        2
# nubia       2
# nothing     2
# motorola    1
# jio         1
# poco        1
# tesla       1
# vivo        1
# lg          1
# lava        1
# Name: count, dtype: int64

# %%
df[(df['processor_brand'].isnull())]
# Out:
#      brand_name                           model   price  rating  has_5g  \
# 21         itel                    itel S16 Pro    6990    67.0   False
# 62         itel                        itel A48    5599    67.0   False
# 70        tecno             Tecno Spark Go 2021    6490    61.0   False
# 257     nothing                 Nothing Phone 4   49990    81.0    True
# 394      realme                       Realme 13   16990    74.0    True
# 440        poco                   Poco C40 Plus   15990    66.0   False
# 536       nubia       Nubia Red Magic 10 Pro 5G   59990    80.0    True
# 558      realme                      Realme C23    9990    78.0   False
# 649        itel      itel S23 (4GB RAM +128 GB)    6849    70.0   False
# 711        oppo                    OPPO Find N4  119900    85.0    True
# 714        itel                        itel A56    5490    67.0   False
# 775       tecno                 Tecno POP 6 LTE    6999    75.0   False
# ...

# %%
df.loc[df[(df['processor_brand'].isnull()) & (df['brand_name'] == 'itel')].index,'processor_brand'] = 'unisoc'

# %%
df[(df['processor_brand'].isnull()) & (df['brand_name'] == 'huawei')]
# Out:
#      brand_name               model  price  rating  has_5g  has_nfc  \
# 787      huawei  Huawei Mate 70 Pro  84990    88.0    True     True
# 879      huawei      Huawei Mate 70  69990    82.0    True     True
# 1416     huawei     Huawei Nova 10z  19990    75.0   False     True
# 1968     huawei    Huawei Pocket S2  79990    79.0   False     True
# 2074     huawei      Huawei Mate 60  61990    81.0    True     True
# 2217     huawei     Huawei Nova Y61  21990    63.0   False    False
#
#       has_ir_blaster processor_brand  num_cores  processor_speed  \
# 787             True             NaN        8.0              NaN
# 879             True             NaN        8.0              NaN
# 1416           False             NaN        8.0              NaN
# 1968           False             NaN        8.0              NaN
# 2074            True             NaN        8.0              NaN
# 2217           False             NaN        8.0              NaN
#
# ...

# %%
df.loc[df[(df['processor_brand'].isnull()) & (df['brand_name'] == 'huawei')].index,'processor_brand'] = 'kirin'

# %%
df[(df['processor_brand'].isnull()) & (df['brand_name'] == 'realme')]
# Out:
#      brand_name             model  price  rating  has_5g  has_nfc  \
# 394      realme         Realme 13  16990    74.0    True    False
# 558      realme        Realme C23   9990    78.0   False    False
# 810      realme  Realme Narzo 60i   7999    61.0   False    False
# 862      realme  Realme Narzo 70i   8999    61.0   False    False
# 947      realme        Realme 12X  17999    75.0    True     True
# 2196     realme   Realme 11 5G SE  20499    75.0    True    False
#
#       has_ir_blaster processor_brand  num_cores  processor_speed  \
# 394            False             NaN        8.0              NaN
# 558            False             NaN        8.0              NaN
# 810            False             NaN        8.0              1.6
# 862            False             NaN        8.0              1.6
# 947            False             NaN        8.0              NaN
# 2196           False             NaN        8.0              NaN
#
# ...

# %%
df.loc[[394,810,862,947],'processor_brand'] = 'kirin'

# %%
df[(df['processor_brand'].isnull()) & (df['brand_name'] == 'realme')]
# Out:
#      brand_name            model  price  rating  has_5g  has_nfc  \
# 558      realme       Realme C23   9990    78.0   False    False
# 2196     realme  Realme 11 5G SE  20499    75.0    True    False
#
#       has_ir_blaster processor_brand  num_cores  processor_speed  \
# 558            False             NaN        8.0              NaN
# 2196           False             NaN        8.0              NaN
#
#       ram_capacity  internal_memory  battery_capacity  \
# 558            4.0             64.0            5000.0
# 2196           8.0            128.0            4500.0
#
#       fast_charging_available  fast_charging  num_rear_cameras  \
# 558                         0            NaN                 3
# 2196                        1           57.0                 3
#
#       num_front_cameras  screen_size resolution  refresh_rate       os  \
# 558                   1         6.59        HD+            60  android
# ...

# %%
df.loc[[558,2196],'processor_brand'] = 'snapdragon'

# %%
df['processor_brand'].value_counts()
# Out:
# processor_brand
# snapdragon    995
# helio         463
# dimensity     454
# exynos        109
# unisoc         85
# bionic         65
# tiger          41
# kirin          32
# mediatek       27
# google         17
# spreadtrum     12
# intel           4
# sc9863a         2
# jlq             1
# fusion          1
# Name: count, dtype: int64

# %%
df['processor_brand'].fillna('dimensity',inplace=True)

# %%
df.isnull().sum()
# Out:
# brand_name                     0
# model                          0
# price                          0
# rating                         0
# has_5g                         0
# has_nfc                        0
# has_ir_blaster                 0
# processor_brand                0
# num_cores                      9
# processor_speed              151
# ram_capacity                   0
# internal_memory                0
# battery_capacity              12
# fast_charging_available        0
# fast_charging                504
# num_rear_cameras               0
# num_front_cameras              0
# screen_size                    0
# resolution                     0
# refresh_rate                   0
# os                             0
# extended_memory_available      0
# extended_upto                  0
# primary_camera_rear            0
# primary_camera_front           6
# dtype: int64

# %% [markdown]
# ### processor_speed

# %%
df[df['processor_speed'].isnull()]['processor_brand'].value_counts()
# Out:
# processor_brand
# snapdragon    42
# dimensity     41
# exynos        19
# bionic        13
# unisoc        10
# kirin         10
# helio          7
# google         6
# mediatek       3
# Name: count, dtype: int64

# %%
df[~(df['processor_speed'].isnull()) & (df['processor_brand'] == 'snapdragon')]['processor_speed'].median()
# Out:
# 2.4

# %%
df.loc[df[(df['processor_speed'].isnull()) & (df['processor_brand'] == 'snapdragon')].index,'processor_speed'] = 2.4

# %%
df[~(df['processor_speed'].isnull()) & (df['processor_brand'] == 'dimensity')]['processor_speed'].median()
# Out:
# 2.4

# %%
df.loc[df[(df['processor_speed'].isnull()) & (df['processor_brand'] == 'dimensity')].index,'processor_speed'] = 2.4

# %%
df[~(df['processor_speed'].isnull()) & (df['processor_brand'] == 'exynos')]['processor_speed'].median()
# Out:
# 2.4

# %%
df.loc[df[(df['processor_speed'].isnull()) & (df['processor_brand'] == 'exynos')].index,'processor_speed'] = 2.4

# %%
df[~(df['processor_speed'].isnull()) & (df['processor_brand'] == 'bionic')]['processor_speed'].median()
# Out:
# 3.22

# %%
df.loc[df[(df['processor_speed'].isnull()) & (df['processor_brand'] == 'bionic')].index,'processor_speed'] = 3.22

# %%
df[~(df['processor_speed'].isnull()) & (df['processor_brand'] == 'unisoc')]['processor_speed'].median()
# Out:
# 1.6

# %%
df.loc[df[(df['processor_speed'].isnull()) & (df['processor_brand'] == 'unisoc')].index,'processor_speed'] = 1.6

# %%
df[~(df['processor_speed'].isnull()) & (df['processor_brand'] == 'kirin')]['processor_speed'].median()
# Out:
# 2.4299999999999997

# %%
df.loc[df[(df['processor_speed'].isnull()) & (df['processor_brand'] == 'kirin')].index,'processor_speed'] = 2.42

# %%
df[~(df['processor_speed'].isnull()) & (df['processor_brand'] == 'helio')]['processor_speed'].median()
# Out:
# 2.0

# %%
df.loc[df[(df['processor_speed'].isnull()) & (df['processor_brand'] == 'helio')].index,'processor_speed'] = 2.0

# %%
df[~(df['processor_speed'].isnull()) & (df['processor_brand'] == 'google')]['processor_speed'].median()
# Out:
# 2.85

# %%
df.loc[df[(df['processor_speed'].isnull()) & (df['processor_brand'] == 'google')].index,'processor_speed'] = 2.85

# %%
df[~(df['processor_speed'].isnull()) & (df['processor_brand'] == 'mediatek')]['processor_speed'].median()
# Out:
# 1.6

# %%
df.loc[df[(df['processor_speed'].isnull()) & (df['processor_brand'] == 'mediatek')].index,'processor_speed'] = 1.6

# %%
df.isnull().sum()
# Out:
# brand_name                     0
# model                          0
# price                          0
# rating                         0
# has_5g                         0
# has_nfc                        0
# has_ir_blaster                 0
# processor_brand                0
# num_cores                      9
# processor_speed                0
# ram_capacity                   0
# internal_memory                0
# battery_capacity              12
# fast_charging_available        0
# fast_charging                504
# num_rear_cameras               0
# num_front_cameras              0
# screen_size                    0
# resolution                     0
# refresh_rate                   0
# os                             0
# extended_memory_available      0
# extended_upto                  0
# primary_camera_rear            0
# primary_camera_front           6
# dtype: int64

# %% [markdown]
# ### num_cores

# %%
df[df['num_cores'].isnull()]
# Out:
#      brand_name                                  model  price  rating  has_5g  \
# 634      xiaomi  Xiaomi Redmi K40 Light Luxury Edition  19999    72.0    True
# 745        lava                          Lava Yuva Pro   6862    72.5   False
# 865       apple                       Apple iPhone XR2  49999    60.0   False
# 1356      nokia                             Nokia G100  10990    72.5   False
# 1479      ikall                   iKall Z19 Prime Plus   7999    64.0   False
# 1484      nokia                           Nokia X50 5G  34999    76.0    True
# 1841      ikall                           iKall K8 New   3999    64.0   False
# 1880      apple                   Apple iPhone 14 Mini  69990    70.0   False
# 2080      honor                       Honor X20 Max 5G  27999    74.0    True
#
#       has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  \
# 634      True            True       dimensity        NaN             2.40
# ...

# %%
df.loc[[865,1880],'num_cores'] = 6

# %%
df.loc[1841,'num_cores'] = 4

# %%
df.loc[df[df['num_cores'].isnull()].index,'num_cores'] = 8

# %%
df[df['num_cores'].isnull()]
# Out:
# Empty DataFrame
# Columns: [brand_name, model, price, rating, has_5g, has_nfc, has_ir_blaster, processor_brand, num_cores, processor_speed, ram_capacity, internal_memory, battery_capacity, fast_charging_available, fast_charging, num_rear_cameras, num_front_cameras, screen_size, resolution, refresh_rate, os, extended_memory_available, extended_upto, primary_camera_rear, primary_camera_front]
# Index: []

# %%
df.isnull().sum()
# Out:
# brand_name                     0
# model                          0
# price                          0
# rating                         0
# has_5g                         0
# has_nfc                        0
# has_ir_blaster                 0
# processor_brand                0
# num_cores                      0
# processor_speed                0
# ram_capacity                   0
# internal_memory                0
# battery_capacity              12
# fast_charging_available        0
# fast_charging                504
# num_rear_cameras               0
# num_front_cameras              0
# screen_size                    0
# resolution                     0
# refresh_rate                   0
# os                             0
# extended_memory_available      0
# extended_upto                  0
# primary_camera_rear            0
# primary_camera_front           6
# dtype: int64

# %% [markdown]
# ### Fast Charging

# %%
df['fast_charging'].value_counts()
# Out:
# fast_charging
# 18.0     287
# 33.0     276
# 67.0     151
# 25.0     122
# 80.0     117
# 66.0      95
# 10.0      94
# 120.0     93
# 15.0      82
# 44.0      76
# 30.0      67
# 65.0      64
# 100.0     61
# 45.0      41
# 150.0     27
# 68.0      27
# 22.0      22
# 20.0      21
# 40.0      19
# 35.0      15
# 125.0      9
# 55.0       8
# 50.0       8
# 200.0      8
# 90.0       5
# 240.0      5
# 88.0       4
# 60.0       4
# 165.0      4
# 21.0       4
# 180.0      3
# 250.0      2
# 210.0      2
# 260.0      1
# 19.0       1
# 8.0        1
# 38.0       1
# 27.0       1
# 135.0      1
# 57.0       1
# Name: count, dtype: int64

# %%
df[df['fast_charging'].isnull()]['brand_name'].value_counts()
# Out:
# brand_name
# apple         60
# realme        42
# vivo          41
# samsung       40
# xiaomi        36
# tecno         30
# nokia         28
# oppo          28
# ikall         27
# motorola      26
# infinix       22
# lava          16
# lenovo        15
# oneplus       11
# itel          11
# honor         10
# huawei         8
# micromax       7
# sony           6
# blackberry     6
# poco           6
# gionee         5
# asus           5
# lg             4
# htc            4
# google         4
# nubia          2
# jio            2
# meizu          1
# iqoo           1
# Name: count, dtype: int64

# %%
df[~(df['fast_charging'].isnull()) & (df['brand_name'] == 'apple')]['fast_charging'].median()
# Out:
# 25.0

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'apple')].index,'fast_charging'] = 25

# %%
df[df['fast_charging'].isnull()]['brand_name'].value_counts()
# Out:
# brand_name
# realme        42
# vivo          41
# samsung       40
# xiaomi        36
# tecno         30
# nokia         28
# oppo          28
# ikall         27
# motorola      26
# infinix       22
# lava          16
# lenovo        15
# itel          11
# oneplus       11
# honor         10
# huawei         8
# micromax       7
# sony           6
# blackberry     6
# poco           6
# gionee         5
# asus           5
# lg             4
# htc            4
# google         4
# nubia          2
# jio            2
# meizu          1
# iqoo           1
# Name: count, dtype: int64

# %%
df[~(df['fast_charging'].isnull()) & (df['brand_name'] == 'realme')]['fast_charging'].median()
# Out:
# 33.0

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'realme')].index,'fast_charging'] = 33

# %%
df[~(df['fast_charging'].isnull()) & (df['brand_name'] == 'vivo')]['fast_charging'].median()
# Out:
# 44.0

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'vivo')].index,'fast_charging'] = 44

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'samsung')].index,'fast_charging'] = df[~(df['fast_charging'].isnull()) & (df['brand_name'] == 'samsung')]['fast_charging'].median()

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'xiaomi')].index,'fast_charging'] = df[~(df['fast_charging'].isnull()) & (df['brand_name'] == 'xiaomi')]['fast_charging'].median()

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'tecno')].index,'fast_charging'] = df[~(df['fast_charging'].isnull()) & (df['brand_name'] == 'tecno')]['fast_charging'].median()

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'nokia')].index,'fast_charging'] = df[~(df['fast_charging'].isnull()) & (df['brand_name'] == 'nokia')]['fast_charging'].median()

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'oppo')].index,'fast_charging'] = df[~(df['fast_charging'].isnull()) & (df['brand_name'] == 'oppo')]['fast_charging'].median()

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'ikall')].index,'fast_charging'] = df[~(df['fast_charging'].isnull()) & (df['brand_name'] == 'ikall')]['fast_charging'].median()

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'motorola')].index,'fast_charging'] = df[~(df['fast_charging'].isnull()) & (df['brand_name'] == 'motorola')]['fast_charging'].median()

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'infinix')].index,'fast_charging'] = df[~(df['fast_charging'].isnull()) & (df['brand_name'] == 'infinix')]['fast_charging'].median()

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'lava')].index,'fast_charging'] = df[~(df['fast_charging'].isnull()) & (df['brand_name'] == 'lava')]['fast_charging'].median()

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'lenovo')].index,'fast_charging'] = df[~(df['fast_charging'].isnull()) & (df['brand_name'] == 'lenovo')]['fast_charging'].median()

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'itel')].index,'fast_charging'] = df[~(df['fast_charging'].isnull()) & (df['brand_name'] == 'itel')]['fast_charging'].median()

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'oneplus')].index,'fast_charging'] = df[~(df['fast_charging'].isnull()) & (df['brand_name'] == 'oneplus')]['fast_charging'].median()

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'honor')].index,'fast_charging'] = df[~(df['fast_charging'].isnull()) & (df['brand_name'] == 'honor')]['fast_charging'].median()

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'huawei')].index,'fast_charging'] = df[~(df['fast_charging'].isnull()) & (df['brand_name'] == 'huawei')]['fast_charging'].median()

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'micromax')].index,'fast_charging'] = df[~(df['fast_charging'].isnull()) & (df['brand_name'] == 'micromax')]['fast_charging'].median()

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'sony')].index,'fast_charging'] = df[~(df['fast_charging'].isnull()) & (df['brand_name'] == 'sony')]['fast_charging'].median()

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'blackberry')].index,'fast_charging'] = df[~(df['fast_charging'].isnull()) & (df['brand_name'] == 'blackberry')]['fast_charging'].median()

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'poco')].index,'fast_charging'] = df[~(df['fast_charging'].isnull()) & (df['brand_name'] == 'poco')]['fast_charging'].median()

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'gionee')].index,'fast_charging'] = df[~(df['fast_charging'].isnull()) & (df['brand_name'] == 'gionee')]['fast_charging'].median()

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'asus')].index,'fast_charging'] = df[~(df['fast_charging'].isnull()) & (df['brand_name'] == 'asus')]['fast_charging'].median()

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'motorola')].index,'fast_charging'] = df[~(df['fast_charging'].isnull()) & (df['brand_name'] == 'motorola')]['fast_charging'].median()

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'lg')].index,'fast_charging'] = df[~(df['fast_charging'].isnull()) & (df['brand_name'] == 'lg')]['fast_charging'].median()

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'htc')].index,'fast_charging'] = df[~(df['fast_charging'].isnull()) & (df['brand_name'] == 'htc')]['fast_charging'].median()

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'google')].index,'fast_charging'] = df[~(df['fast_charging'].isnull()) & (df['brand_name'] == 'google')]['fast_charging'].median()

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'nubia')].index,'fast_charging'] = df[~(df['fast_charging'].isnull()) & (df['brand_name'] == 'nubia')]['fast_charging'].median()

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'jio')].index,'fast_charging'] = df[~(df['fast_charging'].isnull()) & (df['brand_name'] == 'jio')]['fast_charging'].median()

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'iqoo')].index,'fast_charging'] = df[~(df['fast_charging'].isnull()) & (df['brand_name'] == 'iqoo')]['fast_charging'].median()

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'meizu')].index,'fast_charging'] = df[~(df['fast_charging'].isnull()) & (df['brand_name'] == 'meizu')]['fast_charging'].median()

# %%
df[df['fast_charging'].isna()]['brand_name'].value_counts()
# Out:
# brand_name
# ikall         27
# blackberry     6
# Name: count, dtype: int64

# %%
df[~(df['fast_charging'].isnull()) & (df['brand_name'] == 'blackberry')]['fast_charging'].median()
# Out:
# nan

# %%
df['fast_charging'].median()
# Out:
# 33.0

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'blackberry')].index,'fast_charging'] = 33

# %%
df.loc[df[(df['fast_charging'].isnull()) & (df['brand_name'] == 'ikall')].index,'fast_charging'] = 33

# %%
df[df['fast_charging'].isna()]['brand_name'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df.isnull().sum()
# Out:
# brand_name                    0
# model                         0
# price                         0
# rating                        0
# has_5g                        0
# has_nfc                       0
# has_ir_blaster                0
# processor_brand               0
# num_cores                     0
# processor_speed               0
# ram_capacity                  0
# internal_memory               0
# battery_capacity             12
# fast_charging_available       0
# fast_charging                 0
# num_rear_cameras              0
# num_front_cameras             0
# screen_size                   0
# resolution                    0
# refresh_rate                  0
# os                            0
# extended_memory_available     0
# extended_upto                 0
# primary_camera_rear           0
# primary_camera_front          6
# dtype: int64

# %% [markdown]
# ### battery_capacity

# %%
df[df['battery_capacity'].isna()]
# Out:
#      brand_name                           model   price  rating  has_5g  \
# 76        apple            Apple iPhone 12 Mini   59900    74.0    True
# 287       apple  Apple iPhone SE 3 2022 (128GB)   54900    61.0    True
# 298       apple          Apple iPhone SE 3 2022   43900    79.5    True
# 504       apple             Apple iPhone 12 Pro  109900    79.0    True
# 505       apple         Apple iPhone 12 Pro Max  119900    80.0    True
# 537       apple         Apple iPhone 12 (128GB)   50999    76.0    True
# 796       apple                 Apple iPhone 12   44999    75.0    True
# 931       apple    Apple iPhone 12 Mini (128GB)   64900    75.0    True
# 1059      apple         Apple iPhone SE Plus 5G   49990    74.0    True
# 1117      apple         Apple iPhone 12 (256GB)   54899    78.0    True
# 1577      apple               Apple iPhone SE 4   49990    68.0    True
# 2086      apple     Apple iPhone 12 Pro (256GB)  119900    80.0    True
#
# ...

# %%
[2227,2018,2018,2815,3687,2815,2815,2227,3140,2815,3279,2815]
# Out:
# [2227, 2018, 2018, 2815, 3687, 2815, 2815, 2227, 3140, 2815, 3279, 2815]

# %%
df.loc[df[df['battery_capacity'].isna()].index,'battery_capacity'] = [2227,2018,2018,2815,3687,2815,2815,2227,3140,2815,3279,2815]

# %%
df.isnull().sum()
# Out:
# brand_name                   0
# model                        0
# price                        0
# rating                       0
# has_5g                       0
# has_nfc                      0
# has_ir_blaster               0
# processor_brand              0
# num_cores                    0
# processor_speed              0
# ram_capacity                 0
# internal_memory              0
# battery_capacity             0
# fast_charging_available      0
# fast_charging                0
# num_rear_cameras             0
# num_front_cameras            0
# screen_size                  0
# resolution                   0
# refresh_rate                 0
# os                           0
# extended_memory_available    0
# extended_upto                0
# primary_camera_rear          0
# primary_camera_front         6
# dtype: int64

# %% [markdown]
# ### primary camera front

# %%
df[df['primary_camera_front'].isna()]
# Out:
#      brand_name                model   price  rating  has_5g  has_nfc  \
# 556      xiaomi  Xiaomi Mi Mix Alpha  199990    80.0    True    False
# 737        asus   Asus Zenfone 8 Pro   59990    89.0    True     True
# 1478     huawei     Huawei Mate V 5G  119990    88.0    True     True
# 1518       itel            itel A23s    4789    67.0   False    False
# 1840      ikall             iKall K2    3499    64.0   False    False
# 2082     xiaomi     Xiaomi Qin 2 Pro    9990    80.0   False    False
#
#       has_ir_blaster processor_brand  num_cores  processor_speed  \
# 556            False      snapdragon        8.0             2.96
# 737            False      snapdragon        8.0             2.84
# 1478           False       dimensity        8.0             2.40
# 1518           False      spreadtrum        4.0             1.40
# 1840           False        mediatek        4.0             1.60
# 2082           False          unisoc        4.0             1.30
#
# ...

# %%
[np.nan,12,np.nan,0.3,2,np.nan]
# Out:
# [nan, 12, nan, 0.3, 2, nan]

# %%
df.loc[df[df['primary_camera_front'].isna()].index,'primary_camera_front'] = [np.nan,12,np.nan,0.3,2,np.nan]

# %%
df[df['primary_camera_front'].isna()]
# Out:
#      brand_name                model   price  rating  has_5g  has_nfc  \
# 556      xiaomi  Xiaomi Mi Mix Alpha  199990    80.0    True    False
# 1478     huawei     Huawei Mate V 5G  119990    88.0    True     True
# 2082     xiaomi     Xiaomi Qin 2 Pro    9990    80.0   False    False
#
#       has_ir_blaster processor_brand  num_cores  processor_speed  \
# 556            False      snapdragon        8.0             2.96
# 1478           False       dimensity        8.0             2.40
# 2082           False          unisoc        4.0             1.30
#
#       ram_capacity  internal_memory  battery_capacity  \
# 556           12.0            512.0            4050.0
# 1478          12.0            512.0            5000.0
# 2082           2.0             64.0            2100.0
#
#       fast_charging_available  fast_charging  num_rear_cameras  \
# 556                         1           40.0                 3
# 1478                        1           66.0                 4
# ...

# %%
df.loc[df[df['primary_camera_front'].isna()].index,'primary_camera_front'] = 0

# %%
df[df['primary_camera_front'].isna()]
# Out:
# Empty DataFrame
# Columns: [brand_name, model, price, rating, has_5g, has_nfc, has_ir_blaster, processor_brand, num_cores, processor_speed, ram_capacity, internal_memory, battery_capacity, fast_charging_available, fast_charging, num_rear_cameras, num_front_cameras, screen_size, resolution, refresh_rate, os, extended_memory_available, extended_upto, primary_camera_rear, primary_camera_front]
# Index: []

# %%
df.isnull().sum()
# Out:
# brand_name                   0
# model                        0
# price                        0
# rating                       0
# has_5g                       0
# has_nfc                      0
# has_ir_blaster               0
# processor_brand              0
# num_cores                    0
# processor_speed              0
# ram_capacity                 0
# internal_memory              0
# battery_capacity             0
# fast_charging_available      0
# fast_charging                0
# num_rear_cameras             0
# num_front_cameras            0
# screen_size                  0
# resolution                   0
# refresh_rate                 0
# os                           0
# extended_memory_available    0
# extended_upto                0
# primary_camera_rear          0
# primary_camera_front         0
# dtype: int64

# %%
df.to_csv("..\Data Cleaning\smartphones_missing_values_cleaned.csv",index=False)
