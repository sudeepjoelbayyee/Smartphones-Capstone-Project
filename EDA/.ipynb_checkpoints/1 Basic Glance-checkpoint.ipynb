# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'..\Data Cleaning\smartphones_cleaned_v3.csv')

# %%
df
# Out:
#      brand_name                                       model  price  rating  \
# 0       oneplus                              OnePlus V Flip  79990    89.0
# 1         tecno                       Tecno Camon 20 Pro 4G  16990    82.0
# 2        xiaomi  Xiaomi Redmi Note 12 Pro (8GB RAM + 256GB)  23799    82.0
# 3        realme                                 Realme 8 5G  16999    75.0
# 4        xiaomi                  Xiaomi Redmi Note 10 JE 5G  10490    74.0
# ...         ...                                         ...    ...     ...
# 2331     realme                         Realme GT 2 Fold 5G  94990    88.0
# 2332    samsung                       Samsung Galaxy F34 5G  15999    83.0
# 2333       vivo                           Vivo Y33t 4G 2023   8499    71.0
# 2334     xiaomi                             Xiaomi 11 LE 5G  24990    83.0
# 2335   motorola                           Motorola Moto E35  11999    70.0
#
#       has_5g  has_nfc  has_ir_blaster processor_brand  num_cores  \
# 0       True     True           False       dimensity        8.0
# 1      False     True           False           helio        8.0
# 2       True    False            True       dimensity        8.0
# 3       True    False           False       dimensity        8.0
# 4       True    False            True      snapdragon        8.0
# ...      ...      ...             ...             ...        ...
# 2331    True     True           False      snapdragon        8.0
# 2332    True     True           False          exynos        8.0
# 2333   False    False           False           helio        8.0
# 2334    True     True            True      snapdragon        8.0
# 2335   False    False           False          unisoc        8.0
#
#       processor_speed  ...  num_rear_cameras  num_front_cameras  screen_size  \
# 0                 3.2  ...                 2                  1         6.78
# 1                 2.2  ...                 3                  1         6.67
# 2                 2.6  ...                 3                  1         6.67
# 3                 2.2  ...                 3                  1         6.50
# 4                 2.0  ...                 3                  1         6.50
# ...               ...  ...               ...                ...          ...
# 2331              3.2  ...                 2                  1         8.00
# 2332              2.4  ...                 3                  1         6.50
# 2333              2.0  ...                 2                  1         6.56
# 2334              2.4  ...                 3                  1         6.55
# 2335              2.0  ...                 3                  1         6.50
#
#         resolution  refresh_rate       os  extended_memory_available  \
# 0     1080 x 2520            120    other                          0
# 1     1080 x 2400            120  android                          1
# 2     1080 x 2400            120  android                          1
# 3     1080 x 2400             90  android                          1
# 4     1080 x 2400             90  android                          1
# ...            ...           ...      ...                        ...
# 2331  1080 x 2460            120  android                          1
# 2332  1080 x 2340            120  android                          1
# 2333   720 x 1612             60  android                          1
# 2334  1080 x 2400             90  android                          0
# 2335   720 x 1600             90  android                          1
#
#       extended_upto primary_camera_rear  primary_camera_front
# 0               NaN                50.0                  32.0
# 1               NaN                64.0                  32.0
# 2               NaN                50.0                  16.0
# 3            1024.0                48.0                  16.0
# 4            1024.0                48.0                   8.0
# ...             ...                 ...                   ...
# 2331            NaN                50.0                  16.0
# 2332         1024.0                50.0                  13.0
# 2333         1024.0                13.0                   8.0
# 2334            NaN                64.0                  20.0
# 2335         1024.0                16.0                   8.0
#
# [2336 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2336 entries, 0 to 2335
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 2336 non-null   object
#  1   model                      2336 non-null   object
#  2   price                      2336 non-null   int64
#  3   rating                     2070 non-null   float64
#  4   has_5g                     2336 non-null   bool
#  5   has_nfc                    2336 non-null   bool
#  6   has_ir_blaster             2336 non-null   bool
#  7   processor_brand            2253 non-null   object
#  8   num_cores                  2327 non-null   float64
#  9   processor_speed            2185 non-null   float64
#  10  ram_capacity               2336 non-null   float64
#  11  internal_memory            2336 non-null   float64
#  12  battery_capacity           2324 non-null   float64
#  13  fast_charging_available    2336 non-null   int64
#  14  fast_charging              1831 non-null   float64
#  15  num_rear_cameras           2336 non-null   int64
#  16  num_front_cameras          2336 non-null   int64
#  17  screen_size                2336 non-null   float64
#  18  resolution                 2336 non-null   object
#  19  refresh_rate               2336 non-null   int64
#  20  os                         2336 non-null   object
#  21  extended_memory_available  2336 non-null   int64
#  22  extended_upto              1168 non-null   float64
#  23  primary_camera_rear        2336 non-null   float64
#  24  primary_camera_front       2330 non-null   float64
# dtypes: bool(3), float64(11), int64(6), object(5)
# memory usage: 408.5+ KB

# %%
df.isnull().sum()
# Out:
# brand_name                      0
# model                           0
# price                           0
# rating                        266
# has_5g                          0
# has_nfc                         0
# has_ir_blaster                  0
# processor_brand                83
# num_cores                       9
# processor_speed               151
# ram_capacity                    0
# internal_memory                 0
# battery_capacity               12
# fast_charging_available         0
# fast_charging                 505
# num_rear_cameras                0
# num_front_cameras               0
# screen_size                     0
# resolution                      0
# refresh_rate                    0
# os                              0
# extended_memory_available       0
# extended_upto                1168
# primary_camera_rear             0
# primary_camera_front            6
# dtype: int64

# %% [markdown]
# ### Brand_names

# %%
df['brand_name'].value_counts()
# Out:
# xiaomi        267
# vivo          263
# samsung       253
# realme        252
# oppo          153
# motorola      151
# tecno         100
# infinix        91
# poco           90
# honor          88
# oneplus        79
# iqoo           71
# huawei         68
# apple          66
# nokia          62
# lava           37
# nubia          29
# itel           29
# lenovo         28
# ikall          27
# asus           26
# google         21
# sony           20
# micromax       11
# nothing        11
# htc             8
# meizu           7
# gionee          7
# lg              7
# blackberry      6
# redmi           4
# jio             3
# tesla           1
# Name: brand_name, dtype: int64

# %%
# plot a graph of top 5 brands
df['brand_name'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: >

# %%
# plot a pie chart of top 5 brands
df['brand_name'].value_counts().head(10).plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='brand_name'>

# %%
df['brand_name'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Price

# %%
df['price'].describe()
# Out:
# count      2336.000000
# mean      31267.787243
# std       32218.946173
# min        3499.000000
# 25%       11959.000000
# 50%       19990.000000
# 75%       38246.750000
# max      480000.000000
# Name: price, dtype: float64

# %%
sns.displot(kind='hist',data=df,x='price',kde=True)

# %%
df['price'].skew()
# Out:
# 3.194531479780936

# %%
sns.boxplot(df['price'])
# Out:
# <Axes: >

# %%
df = df[df['price']<200000]

# %%
df['price'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### rating

# %%
df['rating'].describe()
# Out:
# count    2069.000000
# mean       77.883519
# std         7.841544
# min        60.000000
# 25%        73.000000
# 50%        79.000000
# 75%        84.000000
# max        89.000000
# Name: rating, dtype: float64

# %%
sns.displot(kind='hist',data=df,x='rating',kde=True)

# %%
df['rating'].skew()
# Out:
# -0.5499320625150897

# %%
sns.boxplot(df['rating'])
# Out:
# <Axes: >

# %%
df['rating'].isnull().sum()
# Out:
# 265

# %% [markdown]
# ### Has_5g

# %%
df['has_5g'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='has_5g'>

# %% [markdown]
# ### has_nfc

# %%
df['has_nfc'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='has_nfc'>

# %% [markdown]
# ### has_ir_blaster

# %%
df['has_ir_blaster'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='has_ir_blaster'>

# %%
df[df['has_ir_blaster']==True]['brand_name'].value_counts()
# Out:
# xiaomi     207
# poco        64
# honor       24
# huawei      22
# iqoo        22
# oppo        21
# vivo        19
# oneplus     17
# realme      13
# redmi        4
# meizu        4
# nubia        3
# samsung      1
# Name: brand_name, dtype: int64

# %%
temp_df = df[df['brand_name']=='redmi']

# %%
df.loc[temp_df.index,'brand_name'] = 'xiaomi'

# %%
df[df['has_ir_blaster']==True]['brand_name'].value_counts()
# Out:
# xiaomi     211
# poco        64
# honor       24
# huawei      22
# iqoo        22
# oppo        21
# vivo        19
# oneplus     17
# realme      13
# meizu        4
# nubia        3
# samsung      1
# Name: brand_name, dtype: int64

# %%
df['processor_brand'].value_counts()
# Out:
# snapdragon    985
# helio         460
# dimensity     454
# exynos        101
# unisoc         81
# bionic         65
# tiger          41
# kirin          22
# spreadtrum     12
# google          9
# tensor          8
# intel           4
# mediatek        2
# sc9863a         2
# jlq             1
# mt              1
# fusion          1
# 1.6 ghz         1
# 1.3 ghz         1
# Name: processor_brand, dtype: int64

# %%
df[df['processor_brand'] == 'tensor']
# Out:
#      brand_name                                   model   price  rating  \
# 330      google                         Google Pixel 9A   49990    78.0
# 432      google                      Google Pixel 8 Pro   92990    81.0
# 435      google  Google Pixel 8 Pro (12GB RAM + 256 GB)  113999    82.0
# 576      google                       Google Pixel 8 5G   75999    77.0
# 1490     google                       Google Pixel Flip   99990    89.0
# 1957     google                         Google Pixel 8A   45990    72.0
# 2011     google       Google Pixel 8 (8GB RAM + 256 GB)   82999    78.0
# 2069     google                         Google Pixel 7A   40990    86.0
#
#       has_5g  has_nfc  has_ir_blaster processor_brand  num_cores  \
# 330     True     True           False          tensor        8.0
# 432     True     True           False          tensor        9.0
# 435     True     True           False          tensor        9.0
# 576     True     True           False          tensor        9.0
# 1490    True     True           False          tensor        8.0
# 1957    True     True           False          tensor        9.0
# 2011    True     True           False          tensor        9.0
# 2069    True     True           False          tensor        8.0
#
#       processor_speed  ...  num_rear_cameras  num_front_cameras  screen_size  \
# 330               NaN  ...                 2                  1          6.3
# 432              3.00  ...                 3                  1          6.7
# 435              3.00  ...                 3                  1          6.7
# 576              3.00  ...                 2                  1          6.2
# 1490             2.85  ...                 2                  1          6.7
# 1957             3.00  ...                 2                  1          6.1
# 2011             3.00  ...                 2                  1          6.2
# 2069             2.85  ...                 2                  1          6.1
#
#         resolution  refresh_rate       os  extended_memory_available  \
# 330   1080 x 2400            120  android                          0
# 432   1344 x 2992            120  android                          1
# 435   1344 x 2992            120  android                          1
# 576   1080 x 2400            120  android                          1
# 1490  1080 x 2640            120    other                          0
# 1957  1080 x 2400             90  android                          0
# 2011  1080 x 2400            120  android                          1
# 2069  1080 x 2400             90  android                          0
#
#       extended_upto primary_camera_rear  primary_camera_front
# 330             NaN               108.0                  13.0
# 432             NaN                50.0                  10.5
# 435             NaN                50.0                  10.5
# 576             NaN                50.0                  10.5
# 1490            NaN                48.0                  10.0
# 1957            NaN                12.2                  10.1
# 2011            NaN                50.0                  10.5
# 2069            NaN                64.0                  13.0
#
# [8 rows x 25 columns]

# %%
df.loc[1481,'processor_brand'] = 'mediatek'
df.loc[1843,'processor_brand'] = 'spreadtrum'
df.loc[358,'processor_brand'] = 'mediatek'

# %%
df.loc[df[df['processor_brand']=='tensor'].index,'processor_brand'] = 'google'

# %%
df['processor_brand'].value_counts()
# Out:
# snapdragon    985
# helio         460
# dimensity     454
# exynos        101
# unisoc         81
# bionic         65
# tiger          41
# kirin          22
# google         17
# spreadtrum     13
# mediatek        4
# intel           4
# sc9863a         2
# jlq             1
# fusion          1
# Name: processor_brand, dtype: int64

# %%
df.loc[df[df['processor_brand']=='mediatek'].index,'processor_brand'] = 'helio'

# %%
df['processor_brand'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='processor_brand'>

# %%
df['num_cores'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='num_cores'>

# %%
df['fast_charging_available'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='fast_charging_available'>

# %%
df['ram_capacity'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='ram_capacity'>

# %%
df['internal_memory'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='internal_memory'>

# %%
df['refresh_rate'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='refresh_rate'>

# %%
df['refresh_rate'].value_counts()
# Out:
# 120    852
# 60     838
# 90     459
# 144    143
# 165     42
# Name: refresh_rate, dtype: int64

# %%
(df['num_rear_cameras'] + df['num_front_cameras']).value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: >

# %%
df['os'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='os'>

# %%
df['extended_memory_available'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='extended_memory_available'>

# %%
df['extended_upto'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='extended_upto'>

# %%
df.to_csv(r'..\Data Cleaning\smartphones_cleaned_v3.csv',index=False)
